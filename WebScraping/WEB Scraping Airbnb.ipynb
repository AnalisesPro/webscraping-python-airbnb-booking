# %% [markdown]
# ### Instalando bibliotecas

# %%
# %%capture
pip install selenium

# %%
# %%capture
pip install xlrd

# %%
# %%capture
pip install geopy

# %%
import time
import json
import os
import unicodedata
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse

# ==========================================
# CONFIGURAÇÃO DE BUSCA (INSIRA AQUI)
# ==========================================
CIDADE = "Pitimbu"
ESTADO = "Paraiba"
CHECK_IN = "2026-03-10"  # Formato: AAAA-MM-DD
CHECK_OUT = "2026-03-15" # Formato: AAAA-MM-DD
# ==========================================

def format_location_for_url(cidade, estado):
    """Formata cidade e estado para o padrão do Airbnb (ex: Conde--Paraiba)."""
    def normalize(text):
        # Remove acentos e substitui espaços por hífens
        text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii')
        return text.strip().replace(" ", "-")
    
    cidade_fmt = normalize(cidade)
    estado_fmt = normalize(estado)
    return f"{cidade_fmt}--{estado_fmt}"

def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--window-size=1920,1080")
    chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
    driver = webdriver.Chrome(options=chrome_options)
    return driver

def inject_dates_to_url(url, checkin, checkout):
    """Adiciona parâmetros de data à URL do Airbnb."""
    u = urlparse(url)
    query = parse_qs(u.query)
    query['check_in'] = [checkin]
    query['check_out'] = [checkout]
    new_query = urlencode(query, doseq=True)
    return urlunparse((u.scheme, u.netloc, u.path, u.params, new_query, u.fragment))

def scrape_airbnb_links():
    # Formatar a localização e construir a URL base
    loc_path = format_location_for_url(CIDADE, ESTADO)
    base_url = f"https://www.airbnb.com.br/s/{loc_path}/homes"
    
    # Injetar datas na URL
    target_url = inject_dates_to_url(base_url, CHECK_IN, CHECK_OUT)
    print(f"Iniciando busca para: {CIDADE}, {ESTADO}")
    print(f"URL de busca: {target_url}")
    
    driver = setup_driver()
    all_links = set()
    page_number = 1
    
    try:
        driver.get(target_url)
        time.sleep(5)
        
        while True:
            print(f"--- Processando página {page_number} ---")
            
            # Tentar fechar popups
            try:
                cookie_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Aceitar') or contains(text(), 'OK')]")
                cookie_button.click()
            except:
                pass

            # Rolar a página
            for _ in range(3):
                driver.execute_script("window.scrollBy(0, 1000);")
                time.sleep(1)
            
            # Seletores de links
            selectors = ['a[itemprop="url"]', 'div[data-testid="card-container"] a', 'a[href*="/rooms/"]']
            links_found = []
            for selector in selectors:
                elements = driver.find_elements(By.CSS_SELECTOR, selector)
                if elements: links_found.extend(elements)
            
            if not links_found:
                print(f"Nenhum link encontrado na página {page_number}.")
                break

            current_page_new_links = 0
            for link in links_found:
                try:
                    href = link.get_attribute('href')
                    if href and '/rooms/' in href:
                        # Mantém as datas na URL do link individual
                        clean_url = href.split('?')[0] + f"?check_in={CHECK_IN}&check_out={CHECK_OUT}"
                        if clean_url not in all_links:
                            all_links.add(clean_url)
                            current_page_new_links += 1
                except:
                    continue
            
            print(f"Novos links nesta página: {current_page_new_links}. Total: {len(all_links)}")

            # Paginação
            try:
                next_button = None
                next_selectors = ['a[aria-label="Próximo"]', 'a[aria-label="Next"]', '//a[contains(@href, "section_offset")]']
                for sel in next_selectors:
                    try:
                        if sel.startswith('//'): next_button = driver.find_element(By.XPATH, sel)
                        else: next_button = driver.find_element(By.CSS_SELECTOR, sel)
                        if next_button: break
                    except: continue

                if next_button:
                    next_url = next_button.get_attribute('href')
                    driver.get(next_url)
                    page_number += 1
                    time.sleep(5)
                else:
                    print("Fim das páginas de resultados.")
                    break
            except:
                break

    finally:
        driver.quit()
    
    return list(all_links)

if __name__ == "__main__":
    links = scrape_airbnb_links()
    
    output_file = "airbnb_links_with_dates.json"
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(links, f, indent=4, ensure_ascii=False)
    
    print(f"\nExtração concluída para {CIDADE}-{ESTADO}!")
    print(f"Total de links únicos extraídos: {len(links)}")
    print(f"Resultados salvos em: {os.path.abspath(output_file)}")
# Out:
# Iniciando busca para: Pitimbu, Paraiba
# URL de busca: https://www.airbnb.com.br/s/Pitimbu--Paraiba/homes?check_in=2026-03-10&check_out=2026-03-15
# --- Processando página 1 ---
# Novos links nesta página: 18. Total: 18
# --- Processando página 2 ---
# Novos links nesta página: 18. Total: 36
# --- Processando página 3 ---
# Novos links nesta página: 18. Total: 54
# --- Processando página 4 ---
# Novos links nesta página: 17. Total: 71
# --- Processando página 5 ---
# Novos links nesta página: 18. Total: 89
# --- Processando página 6 ---
# Novos links nesta página: 18. Total: 107
# --- Processando página 7 ---
# Novos links nesta página: 15. Total: 122
# Fim das páginas de resultados.
#
# Extração concluída para Pitimbu-Paraiba!
# Total de links únicos extraídos: 122
# Resultados salvos em: C:\Users\diego\Downloads\WebScraping\Airbnb\airbnb_links_with_dates.json

# %%
import time
import json
import os
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from geopy.geocoders import Nominatim

def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--window-size=1920,1080")
    chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
    driver = webdriver.Chrome(options=chrome_options)
    return driver

def extract_number(text):
    if not text: return 0
    match = re.search(r'(\d+)', str(text))
    return int(match.group(1)) if match else 0

def main():
    input_file = "airbnb_links_with_dates.json"
    output_file = "airbnb_resultado_final_detalhado.csv"
    failed_links_file = "airbnb_links_falhos.json"
    
    if not os.path.exists(input_file):
        print(f"Erro: {input_file} não encontrado. Execute o script de extração de links primeiro.")
        return
    
    with open(input_file, "r") as f:
        room_links = json.load(f)

    driver = setup_driver()
    geolocator = Nominatim(user_agent="airbnb_final_exhaustive_scraper_v3")
    dados_coletados = []
    links_falhou = []

    # Processar links
    links_para_processar = room_links
    print(f"Iniciando extração detalhada de {len(links_para_processar)} anúncios...")

    for i, link in enumerate(links_para_processar):
        try:
            print(f"[{i+1}/{len(links_para_processar)}] Processando: {link}")
            driver.get(link)
            time.sleep(12) # Tempo para carregar dados dinâmicos
            
            # 1. Título
            try:
                titulo = driver.find_element(By.TAG_NAME, "h1").text
            except:
                titulo = "N/A"

            # 2. Capacidade (Hóspedes, Quartos, Camas, Banheiros) - Lógica Robusta
            hospedes = quartos = camas = banheiros = 0
            try:
                # O Airbnb costuma colocar isso em uma lista (ol/li) ou em uma div de visão geral
                # Vamos tentar capturar o texto de toda a seção de detalhes
                overview_selectors = [
                    'div[data-section-id="OVERVIEW_DEFAULT_V2"]',
                    'div[data-testid="listing-details-not-standalone"]',
                    'ol._199960j' # Classe comum para a lista de detalhes
                ]
                
                overview_text = ""
                for sel in overview_selectors:
                    try:
                        overview_text = driver.find_element(By.CSS_SELECTOR, sel).text
                        if overview_text: break
                    except: continue
                
                if not overview_text:
                    # Fallback: pegar o texto de todos os itens da lista
                    items = driver.find_elements(By.XPATH, "//ol/li")
                    overview_text = " ".join([it.text for it in items])

                # Regex em português para capturar os números
                h_m = re.search(r'(\d+)\s+hóspede', overview_text)
                q_m = re.search(r'(\d+)\s+quarto', overview_text)
                c_m = re.search(r'(\d+)\s+cama', overview_text)
                b_m = re.search(r'(\d+)\s+banheiro', overview_text)
                
                if h_m: hospedes = int(h_m.group(1))
                if q_m: quartos = int(q_m.group(1))
                if c_m: camas = int(c_m.group(1))
                if b_m: banheiros = int(b_m.group(1))
            except Exception as e:
                print(f"Erro ao extrair capacidade: {e}")

            # 3. Anfitrião e Tempo de Hospedagem
            anfitriao = tempo_hospedando = "N/A"
            try:
                host_section = driver.find_element(By.CSS_SELECTOR, 'div[data-section-id="HOST_OVERVIEW_DEFAULT"], div[data-testid="host-profile-container"]')
                host_text = host_section.text
                
                # Nome
                name_m = re.search(r'Anfitriã\(o\):\s*([^\n]+)', host_text)
                if name_m:
                    anfitriao = name_m.group(1).strip()
                else:
                    anfitriao = host_section.find_element(By.TAG_NAME, "h2").text.replace("Anfitriã(o): ", "").strip()
                
                # Tempo
                tempo_m = re.search(r'(\d+)\s+anos?\s+hospedando', host_text)
                if tempo_m:
                    tempo_hospedando = f"{tempo_m.group(1)} anos"
            except:
                pass

            # 4. Preços e Taxas
            preco_noite = preco_total = taxa_limpeza = noites = "N/A"
            try:
                price_widget = driver.find_element(By.CSS_SELECTOR, 'div[data-testid="book-it-default"]')
                w_text = price_widget.text
                
                n_m = re.search(r'(R\$\s*[\d\.,]+)\s*[x/]', w_text)
                if n_m: preco_noite = n_m.group(1).strip()
                
                t_m = re.search(r'Total\s+(R\$\s*[\d\.,]+)', w_text)
                if t_m: preco_total = t_m.group(1).strip()
                
                nts_m = re.search(r'(\d+)\s+noites', w_text)
                if nts_m: noites = nts_m.group(1).strip()

                l_m = re.search(r'Taxa de limpeza\s+(R\$\s*[\d\.,]+)', w_text)
                if l_m: taxa_limpeza = l_m.group(1).strip()
            except:
                pass

            # 5. Coordenadas e Endereço
            lat = lng = endereco = "N/A"
            try:
                coords_match = re.findall(r'"latitude":([\d\.\-]+),"longitude":([\d\.\-]+)', driver.page_source)
                if coords_match:
                    lat, lng = coords_match[0]
                    location = geolocator.reverse((lat, lng), language='pt')
                    endereco = location.address if location else "N/A"
            except:
                pass

            dados_coletados.append({
                "Link": link,
                "Titulo": titulo,
                "Anfitriao": anfitriao,
                "Tempo_Hospedando": tempo_hospedando,
                "Preco_Noite": preco_noite,
                "Noites": noites,
                "Taxa_Limpeza": taxa_limpeza,
                "Preco_Total": preco_total,
                "Hospedes": hospedes,
                "Quartos": quartos,
                "Camas": camas,
                "Banheiros": banheiros,
                "Latitude": lat,
                "Longitude": lng,
                "Endereco": endereco
            })

        except Exception as e:
            print(f"⚠️ Falhou: {link} | Erro: {e}")
            links_falhou.append(link)

    # Salvar resultados
    df = pd.DataFrame(dados_coletados)
    df.to_csv(output_file, index=False, encoding='utf-8-sig')
    
    # Salvar links falhos
    if links_falhou:
        with open(failed_links_file, "w", encoding="utf-8") as f:
            json.dump(links_falhou, f, indent=4, ensure_ascii=False)
        print(f"Links falhos salvos em: {failed_links_file}")

    print(f"\nSucesso! {len(dados_coletados)} registros salvos em {output_file}")
    driver.quit()

if __name__ == "__main__":
    main()
# Out:
# Iniciando extração detalhada de 124 anúncios...
# [1/124] Processando: https://www.airbnb.com.br/rooms/1328425414867103525?check_in=2026-03-10&check_out=2026-03-15
# [2/124] Processando: https://www.airbnb.com.br/rooms/1413898424237252215?check_in=2026-03-10&check_out=2026-03-15
# [3/124] Processando: https://www.airbnb.com.br/rooms/1245033477659347356?check_in=2026-03-10&check_out=2026-03-15
# [4/124] Processando: https://www.airbnb.com.br/rooms/1295497421656009479?check_in=2026-03-10&check_out=2026-03-15
# [5/124] Processando: https://www.airbnb.com.br/rooms/1582501793715991322?check_in=2026-03-10&check_out=2026-03-15
# [6/124] Processando: https://www.airbnb.com.br/rooms/936178989029521352?check_in=2026-03-10&check_out=2026-03-15
# [7/124] Processando: https://www.airbnb.com.br/rooms/1601366689830033823?check_in=2026-03-10&check_out=2026-03-15
# [8/124] Processando: https://www.airbnb.com.br/rooms/622256605313091061?check_in=2026-03-10&check_out=2026-03-15
# [9/124] Processando: https://www.airbnb.com.br/rooms/953694912398375110?check_in=2026-03-10&check_out=2026-03-15
# [10/124] Processando: https://www.airbnb.com.br/rooms/1121029804870804136?check_in=2026-03-10&check_out=2026-03-15
# [11/124] Processando: https://www.airbnb.com.br/rooms/1593581329096189728?check_in=2026-03-10&check_out=2026-03-15
# [12/124] Processando: https://www.airbnb.com.br/rooms/1260692635316694370?check_in=2026-03-10&check_out=2026-03-15
# [13/124] Processando: https://www.airbnb.com.br/rooms/1328908101730788116?check_in=2026-03-10&check_out=2026-03-15
# [14/124] Processando: https://www.airbnb.com.br/rooms/25110222?check_in=2026-03-10&check_out=2026-03-15
# [15/124] Processando: https://www.airbnb.com.br/rooms/1309465216037110107?check_in=2026-03-10&check_out=2026-03-15
# [16/124] Processando: https://www.airbnb.com.br/rooms/1075461800637272443?check_in=2026-03-10&check_out=2026-03-15
# [17/124] Processando: https://www.airbnb.com.br/rooms/1049168386873995827?check_in=2026-03-10&check_out=2026-03-15
# [18/124] Processando: https://www.airbnb.com.br/rooms/1597078510409585740?check_in=2026-03-10&check_out=2026-03-15
# [19/124] Processando: https://www.airbnb.com.br/rooms/1576082261654330926?check_in=2026-03-10&check_out=2026-03-15
# [20/124] Processando: https://www.airbnb.com.br/rooms/54004814?check_in=2026-03-10&check_out=2026-03-15
# [21/124] Processando: https://www.airbnb.com.br/rooms/1156699808993983688?check_in=2026-03-10&check_out=2026-03-15
# [22/124] Processando: https://www.airbnb.com.br/rooms/46510311?check_in=2026-03-10&check_out=2026-03-15
# [23/124] Processando: https://www.airbnb.com.br/rooms/556673563014806366?check_in=2026-03-10&check_out=2026-03-15
# [24/124] Processando: https://www.airbnb.com.br/rooms/1390154960462571369?check_in=2026-03-10&check_out=2026-03-15
# [25/124] Processando: https://www.airbnb.com.br/rooms/1575591566430971214?check_in=2026-03-10&check_out=2026-03-15
# [26/124] Processando: https://www.airbnb.com.br/rooms/561507037415095919?check_in=2026-03-10&check_out=2026-03-15
# [27/124] Processando: https://www.airbnb.com.br/rooms/993485167562931737?check_in=2026-03-10&check_out=2026-03-15
# [28/124] Processando: https://www.airbnb.com.br/rooms/1393497716423801747?check_in=2026-03-10&check_out=2026-03-15
# [29/124] Processando: https://www.airbnb.com.br/rooms/1601362500490739377?check_in=2026-03-10&check_out=2026-03-15
# [30/124] Processando: https://www.airbnb.com.br/rooms/770123249125344340?check_in=2026-03-10&check_out=2026-03-15
# [31/124] Processando: https://www.airbnb.com.br/rooms/922612547150123540?check_in=2026-03-10&check_out=2026-03-15
# [32/124] Processando: https://www.airbnb.com.br/rooms/1600392211149095177?check_in=2026-03-10&check_out=2026-03-15
# [33/124] Processando: https://www.airbnb.com.br/rooms/44084250?check_in=2026-03-10&check_out=2026-03-15
# [34/124] Processando: https://www.airbnb.com.br/rooms/1601324497733129327?check_in=2026-03-10&check_out=2026-03-15
# [35/124] Processando: https://www.airbnb.com.br/rooms/49938029?check_in=2026-03-10&check_out=2026-03-15
# [36/124] Processando: https://www.airbnb.com.br/rooms/1411118747273288397?check_in=2026-03-10&check_out=2026-03-15
# [37/124] Processando: https://www.airbnb.com.br/rooms/1434721234805510238?check_in=2026-03-10&check_out=2026-03-15
# [38/124] Processando: https://www.airbnb.com.br/rooms/1407757450319553428?check_in=2026-03-10&check_out=2026-03-15
# [39/124] Processando: https://www.airbnb.com.br/rooms/949096507158423993?check_in=2026-03-10&check_out=2026-03-15
# [40/124] Processando: https://www.airbnb.com.br/rooms/1120498800661007344?check_in=2026-03-10&check_out=2026-03-15
# [41/124] Processando: https://www.airbnb.com.br/rooms/1610334074318316498?check_in=2026-03-10&check_out=2026-03-15
# [42/124] Processando: https://www.airbnb.com.br/rooms/1371032909382004605?check_in=2026-03-10&check_out=2026-03-15
# [43/124] Processando: https://www.airbnb.com.br/rooms/1538560033801514479?check_in=2026-03-10&check_out=2026-03-15
# [44/124] Processando: https://www.airbnb.com.br/rooms/1056498310358057502?check_in=2026-03-10&check_out=2026-03-15
# [45/124] Processando: https://www.airbnb.com.br/rooms/1318342711137214928?check_in=2026-03-10&check_out=2026-03-15
# [46/124] Processando: https://www.airbnb.com.br/rooms/1601328410867803842?check_in=2026-03-10&check_out=2026-03-15
# [47/124] Processando: https://www.airbnb.com.br/rooms/1110108820411060500?check_in=2026-03-10&check_out=2026-03-15
# [48/124] Processando: https://www.airbnb.com.br/rooms/834972356397374213?check_in=2026-03-10&check_out=2026-03-15
# [49/124] Processando: https://www.airbnb.com.br/rooms/1561067681456727873?check_in=2026-03-10&check_out=2026-03-15
# [50/124] Processando: https://www.airbnb.com.br/rooms/908185418115459485?check_in=2026-03-10&check_out=2026-03-15
# [51/124] Processando: https://www.airbnb.com.br/rooms/1529308891276907736?check_in=2026-03-10&check_out=2026-03-15
# [52/124] Processando: https://www.airbnb.com.br/rooms/52877371?check_in=2026-03-10&check_out=2026-03-15
# [53/124] Processando: https://www.airbnb.com.br/rooms/523174743120928075?check_in=2026-03-10&check_out=2026-03-15
# [54/124] Processando: https://www.airbnb.com.br/rooms/825449676691784915?check_in=2026-03-10&check_out=2026-03-15
# [55/124] Processando: https://www.airbnb.com.br/rooms/40657953?check_in=2026-03-10&check_out=2026-03-15
# [56/124] Processando: https://www.airbnb.com.br/rooms/1292226693329199039?check_in=2026-03-10&check_out=2026-03-15
# [57/124] Processando: https://www.airbnb.com.br/rooms/1221301049658666474?check_in=2026-03-10&check_out=2026-03-15
# [58/124] Processando: https://www.airbnb.com.br/rooms/1271995804023770341?check_in=2026-03-10&check_out=2026-03-15
# [59/124] Processando: https://www.airbnb.com.br/rooms/1200573947146284113?check_in=2026-03-10&check_out=2026-03-15
# [60/124] Processando: https://www.airbnb.com.br/rooms/557102356149469489?check_in=2026-03-10&check_out=2026-03-15
# [61/124] Processando: https://www.airbnb.com.br/rooms/1602150163654611822?check_in=2026-03-10&check_out=2026-03-15
# [62/124] Processando: https://www.airbnb.com.br/rooms/706659993728352250?check_in=2026-03-10&check_out=2026-03-15
# [63/124] Processando: https://www.airbnb.com.br/rooms/999411265217908132?check_in=2026-03-10&check_out=2026-03-15
# [64/124] Processando: https://www.airbnb.com.br/rooms/1275982510314590971?check_in=2026-03-10&check_out=2026-03-15
# [65/124] Processando: https://www.airbnb.com.br/rooms/1020090679025548380?check_in=2026-03-10&check_out=2026-03-15
# [66/124] Processando: https://www.airbnb.com.br/rooms/1601368076524978950?check_in=2026-03-10&check_out=2026-03-15
# [67/124] Processando: https://www.airbnb.com.br/rooms/49174894?check_in=2026-03-10&check_out=2026-03-15
# [68/124] Processando: https://www.airbnb.com.br/rooms/1348610684191655871?check_in=2026-03-10&check_out=2026-03-15
# [69/124] Processando: https://www.airbnb.com.br/rooms/684684054447241218?check_in=2026-03-10&check_out=2026-03-15
# [70/124] Processando: https://www.airbnb.com.br/rooms/612831234800097685?check_in=2026-03-10&check_out=2026-03-15
# [71/124] Processando: https://www.airbnb.com.br/rooms/1078198233538506361?check_in=2026-03-10&check_out=2026-03-15
# [72/124] Processando: https://www.airbnb.com.br/rooms/980658616498137189?check_in=2026-03-10&check_out=2026-03-15
# [73/124] Processando: https://www.airbnb.com.br/rooms/1385400861386632668?check_in=2026-03-10&check_out=2026-03-15
# [74/124] Processando: https://www.airbnb.com.br/rooms/1221940349406809888?check_in=2026-03-10&check_out=2026-03-15
# [75/124] Processando: https://www.airbnb.com.br/rooms/1559136103840782590?check_in=2026-03-10&check_out=2026-03-15
# [76/124] Processando: https://www.airbnb.com.br/rooms/47998205?check_in=2026-03-10&check_out=2026-03-15
# [77/124] Processando: https://www.airbnb.com.br/rooms/566429515308439484?check_in=2026-03-10&check_out=2026-03-15
# [78/124] Processando: https://www.airbnb.com.br/rooms/53921113?check_in=2026-03-10&check_out=2026-03-15
# [79/124] Processando: https://www.airbnb.com.br/rooms/1540647891729158486?check_in=2026-03-10&check_out=2026-03-15
# [80/124] Processando: https://www.airbnb.com.br/rooms/577687800286188810?check_in=2026-03-10&check_out=2026-03-15
# [81/124] Processando: https://www.airbnb.com.br/rooms/1328914502195829178?check_in=2026-03-10&check_out=2026-03-15
# [82/124] Processando: https://www.airbnb.com.br/rooms/1310854058626914002?check_in=2026-03-10&check_out=2026-03-15
# [83/124] Processando: https://www.airbnb.com.br/rooms/1272525536317654153?check_in=2026-03-10&check_out=2026-03-15
# [84/124] Processando: https://www.airbnb.com.br/rooms/1546962879864231371?check_in=2026-03-10&check_out=2026-03-15
# [85/124] Processando: https://www.airbnb.com.br/rooms/1339766028158316035?check_in=2026-03-10&check_out=2026-03-15
# [86/124] Processando: https://www.airbnb.com.br/rooms/1567697952081551122?check_in=2026-03-10&check_out=2026-03-15
# [87/124] Processando: https://www.airbnb.com.br/rooms/1365157898188609151?check_in=2026-03-10&check_out=2026-03-15
# [88/124] Processando: https://www.airbnb.com.br/rooms/1067634667759848618?check_in=2026-03-10&check_out=2026-03-15
# [89/124] Processando: https://www.airbnb.com.br/rooms/1363413348213029054?check_in=2026-03-10&check_out=2026-03-15
# [90/124] Processando: https://www.airbnb.com.br/rooms/1075291460468051482?check_in=2026-03-10&check_out=2026-03-15
# [91/124] Processando: https://www.airbnb.com.br/rooms/45518715?check_in=2026-03-10&check_out=2026-03-15
# [92/124] Processando: https://www.airbnb.com.br/rooms/1529066348415805550?check_in=2026-03-10&check_out=2026-03-15
# [93/124] Processando: https://www.airbnb.com.br/rooms/815758133526110855?check_in=2026-03-10&check_out=2026-03-15
# [94/124] Processando: https://www.airbnb.com.br/rooms/1335709008689140171?check_in=2026-03-10&check_out=2026-03-15
# [95/124] Processando: https://www.airbnb.com.br/rooms/1395854710384506912?check_in=2026-03-10&check_out=2026-03-15
# [96/124] Processando: https://www.airbnb.com.br/rooms/1129723020509164329?check_in=2026-03-10&check_out=2026-03-15
# [97/124] Processando: https://www.airbnb.com.br/rooms/1572690319551056332?check_in=2026-03-10&check_out=2026-03-15
# [98/124] Processando: https://www.airbnb.com.br/rooms/50564824?check_in=2026-03-10&check_out=2026-03-15
# [99/124] Processando: https://www.airbnb.com.br/rooms/797121685715650007?check_in=2026-03-10&check_out=2026-03-15
# [100/124] Processando: https://www.airbnb.com.br/rooms/1466827002164707036?check_in=2026-03-10&check_out=2026-03-15
# [101/124] Processando: https://www.airbnb.com.br/rooms/1032746996749794474?check_in=2026-03-10&check_out=2026-03-15
# [102/124] Processando: https://www.airbnb.com.br/rooms/1587596627025668714?check_in=2026-03-10&check_out=2026-03-15
# [103/124] Processando: https://www.airbnb.com.br/rooms/1599413684760341334?check_in=2026-03-10&check_out=2026-03-15
# [104/124] Processando: https://www.airbnb.com.br/rooms/1332456724184498119?check_in=2026-03-10&check_out=2026-03-15
# [105/124] Processando: https://www.airbnb.com.br/rooms/1033422101236166705?check_in=2026-03-10&check_out=2026-03-15
# [106/124] Processando: https://www.airbnb.com.br/rooms/52054344?check_in=2026-03-10&check_out=2026-03-15
# [107/124] Processando: https://www.airbnb.com.br/rooms/1026218253634582732?check_in=2026-03-10&check_out=2026-03-15
# [108/124] Processando: https://www.airbnb.com.br/rooms/1528973615526489368?check_in=2026-03-10&check_out=2026-03-15
# [109/124] Processando: https://www.airbnb.com.br/rooms/1244320428264850515?check_in=2026-03-10&check_out=2026-03-15
# [110/124] Processando: https://www.airbnb.com.br/rooms/1468169166959962599?check_in=2026-03-10&check_out=2026-03-15
# [111/124] Processando: https://www.airbnb.com.br/rooms/31314069?check_in=2026-03-10&check_out=2026-03-15
# [112/124] Processando: https://www.airbnb.com.br/rooms/1597746056216428338?check_in=2026-03-10&check_out=2026-03-15
# [113/124] Processando: https://www.airbnb.com.br/rooms/1484072625804842558?check_in=2026-03-10&check_out=2026-03-15
# [114/124] Processando: https://www.airbnb.com.br/rooms/547112749672168417?check_in=2026-03-10&check_out=2026-03-15
# [115/124] Processando: https://www.airbnb.com.br/rooms/1272804959513885089?check_in=2026-03-10&check_out=2026-03-15
# [116/124] Processando: https://www.airbnb.com.br/rooms/1604358771654231934?check_in=2026-03-10&check_out=2026-03-15
# [117/124] Processando: https://www.airbnb.com.br/rooms/1599277277251606394?check_in=2026-03-10&check_out=2026-03-15
# [118/124] Processando: https://www.airbnb.com.br/rooms/1370529520986742932?check_in=2026-03-10&check_out=2026-03-15
# [119/124] Processando: https://www.airbnb.com.br/rooms/1604393431625832582?check_in=2026-03-10&check_out=2026-03-15
# [120/124] Processando: https://www.airbnb.com.br/rooms/1208054935029542051?check_in=2026-03-10&check_out=2026-03-15
# [121/124] Processando: https://www.airbnb.com.br/rooms/804884112461812248?check_in=2026-03-10&check_out=2026-03-15
# [122/124] Processando: https://www.airbnb.com.br/rooms/1241536871037254621?check_in=2026-03-10&check_out=2026-03-15
# [123/124] Processando: https://www.airbnb.com.br/rooms/53488995?check_in=2026-03-10&check_out=2026-03-15
# [124/124] Processando: https://www.airbnb.com.br/rooms/1594407143257254734?check_in=2026-03-10&check_out=2026-03-15
#
# Sucesso! 124 registros salvos em airbnb_resultado_final_detalhado.csv
